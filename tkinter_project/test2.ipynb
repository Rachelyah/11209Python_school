# %%
# 測試寫入pitchings.csv檔案到squlite資料庫

import csv

cpbl_pitchings_csv = 'pitchings.csv'

try:
    pitchings_file=open(cpbl_pitchings_csv, mode='r', encoding='utf-8', newline='')
    pitchings_dictReader = csv.DictReader(pitchings_file)
    pitchings_list = list(pitchings_dictReader)
    #print(pitchings_list)
    #print(pitchings_list[23])
    for pitchings in pitchings_list:
        print(pitchings['Name'])
        #補上寫入的資料，可以寫在insertdata
    pitchings_file.close() 
    print(pitchings_file.closed)
except Exception as e:
        print(f'讀檔錯誤,{e}')

# %%
# 測試寫入pitchings.csv檔案到squlite資料庫

import csv

cpbl_pitchings_csv = 'pitchings.csv'

try:
    with open (cpbl_pitchings_csv, mode='r', encoding='utf-8', newline='') as pitchings_file:
        pitchings_dictReader = csv.DictReader(pitchings_file)
        for row in pitchings_dictReader:
            row['記錄年份'] = '2022'
            #row = list(pitchings_dictReader)
        print(row)
        #print(pitchings_list)
        #print(pitchings_list[23])
        #for pitchings in pitchings_list:
            #print(pitchings)
            #補上寫入的資料，可以寫在insertdata
    #print(pitchings_file.closed)
except Exception as e:
        print(f'讀檔錯誤,{e}')
# Out:
# {'ID': '0000006884', 'Name': '霸曼', 'Team ID': 'AAA', 'Team Name': '味全', 'G': '1', 'GS': '1', 'GR': '0', 'CG': '0', 'SHO': '0', 'NBB': '0', 'W': '1', 'L': '0', 'SV': '0', 'HLD': '0', 'IP': '7.0', 'BF': '23', 'NP': '89', 'H': '3', 'HR': '0', 'BB': '0', 'IBB': '0', 'HBP': '0', 'SO': '5', 'WP': '0', 'BK': '0', 'R': '0', 'ER': '0', 'GO': '5', 'FO': '10', '記錄年份': '2022'}

# %%
cpbl_pitchings_csv = 'pitchings.csv'

with open(cpbl_pitchings_csv, 'r', encoding='utf-8') as csvfile:
        csv_reader = csv.DictReader(csvfile)
        for row in csv_reader:
                # 在每一行的字典中添加 '更新時間' 欄位
                row['更新時間'] = '2022'
print(row)
# Out:
# {'ID': '0000006884', 'Name': '霸曼', 'Team ID': 'AAA', 'Team Name': '味全', 'G': '1', 'GS': '1', 'GR': '0', 'CG': '0', 'SHO': '0', 'NBB': '0', 'W': '1', 'L': '0', 'SV': '0', 'HLD': '0', 'IP': '7.0', 'BF': '23', 'NP': '89', 'H': '3', 'HR': '0', 'BB': '0', 'IBB': '0', 'HBP': '0', 'SO': '5', 'WP': '0', 'BK': '0', 'R': '0', 'ER': '0', 'GO': '5', 'FO': '10', '更新時間': '2022'}

# %%
cpbl_pitchings_csv = 'pitchings.csv'

# 建立一個新的csv文件名稱，用於保存修改後的資料
new_csv = 'pitchings_2022.csv'

with open(cpbl_pitchings_csv, 'r', encoding='utf-8') as csvfile:
    csv_reader = csv.DictReader(csvfile)
    
    # 取得欄位名稱，並加上Year欄位
    fieldnames= csv_reader.fieldnames + ['Year']
    
    # 開啟新的csv文件，寫入欄位名稱
    with open(new_csv, 'w', encoding='utf-8', newline='') as output_file:
        csv_writer = csv.DictWriter(output_file, fieldnames=fieldnames)
        csv_writer.writeheader()
        
    # 將原本的資料寫入新的csv，同時在每一筆資料的最後面加上 'Year': '2022'
        for row in csv_reader:
            row['Year'] = '2022'
            csv_writer.writerow(row)

print(f'修改後的資料已寫入 {new_csv}')

pitchings_2022 = 'pitchings_modified.csv'
with open (pitchings_2022, mode='r', encoding='utf-8', newline='') as pitchings_file:
    pitchings_dictReader = csv.DictReader(pitchings_file)
    print(list(pitchings_dictReader))
# Out:
# 修改後的資料已寫入 pitchings_2022.csv
# ...

# %%
#暫存

def __open_cpbl_data() ->list[dict]:
    
    cpbl_pitchings_csv = 'pitchings.csv'

    try:
        with open (cpbl_pitchings_csv, mode='r', encoding='utf-8', newline='') as pitchings_file:
            pitchings_dictReader = csv.DictReader(pitchings_file)
            pitchings_list = list(pitchings_dictReader)
        print(pitchings_file.closed)
        return pitchings_list
    except Exception as e:
        return print(f'讀檔錯誤,{e}')

# %%
cpbl_pitchings_csv = 'pitchings.csv'

    # 建立一個新的csv文件，加入紀錄年份2022後儲存
new_csv = 'pitchings_2022.csv'

with open(cpbl_pitchings_csv, 'r', encoding='utf-8') as csvfile:
        csv_reader = csv.DictReader(csvfile)
        
        # 取得欄位名稱，並加上Year欄位
        fieldnames= csv_reader.fieldnames + ['Year']
        
        # 開啟新的csv文件，寫入欄位名稱
        with open(new_csv, 'w', encoding='utf-8', newline='') as output_file:
            csv_writer = csv.DictWriter(output_file, fieldnames=fieldnames)
            csv_writer.writeheader()
            
        # 將原本的資料寫入新的csv，同時在每一筆資料的最後面加上 'Year': '2022'
            for row in csv_reader:
                row['Year'] = '2022'
                csv_writer.writerow(row)
        print(f'修改後的資料已寫入 {new_csv}')

    #讀取新的csv檔案
pitchings_2022 = 'pitchings_modified.csv'
try:
        with open (pitchings_2022, mode='r', encoding='utf-8', newline='') as pitchings_file:
            pitchings_dictReader = csv.DictReader(pitchings_file)
            print('讀取成功')
            #print(list(pitchings_dictReader))
except Exception as e:
            print(f'讀取錯誤{e}')
# Out:
# 修改後的資料已寫入 pitchings_2022.csv
# 讀取成功

# %%
#下拉選單

import tkinter as tk
from tkinter import ttk

root = tk.Tk()
root.title('oxxo.studio')
root.geometry('200x200')

box = ttk.Combobox(root, values=['七龍珠','海賊王','鬼滅之刃','灌籃高手','排球少年'])
box.pack()

root.mainloop()

# %%
# 測試下拉選單

import tkinter as tk
from tkinter import ttk

root = tk.Tk()
root.title('oxxo.studio')
root.geometry('200x200')

def show():
    a.set(f'{box.current()}:{box.get()}')    # 顯示索引值與內容

a = tk.StringVar()                           # 定義變數
a.set('')

label = tk.Label(root, textvariable=a)       # 建立標籤，內容為變數
label.pack()

#下拉選單
box = ttk.Combobox(root,
                    width=15,
                    values=['七龍珠','海賊王','鬼滅之刃','灌籃高手','排球少年'])
box.pack()

btn = tk.Button(root, text='顯示', command=show)   # 建立按鈕，點擊按鈕時，執行 show 函式
btn.pack()

root.mainloop()

# %%
from tkinter import *
import Pmw

root = Tk()
root.title('ButtonBox')
Pmw.initialise() #初始化pmw模組

#當按下按鈕時調用的function
def buttonPress(btn):
    print('The "%s" button was pressed' % btn)


#當使用者按下enter時，視為模擬按下OK的按鈕的方法
def defaultKey(event):
    buttonBox.invoke()

#labelpos 設定視窗的起始位置
buttonBox = Pmw.ButtonBox(root, labelpos='nw', label_text='ButtonBox:')
buttonBox.pack(fill=BOTH, expand=1, padx=10, pady=10)

buttonBox.add('OK',     command = lambda b='ok':     buttonPress(b))
buttonBox.add('Apply',  command = lambda b='apply':  buttonPress(b))
buttonBox.add('Cancel', command = lambda b='cancel': buttonPress(b))

# Set the default button (the one executed when <Enter> is hit).
buttonBox.setdefault('OK')
root.bind('<Return>', defaultKey)
root.focus_set()

buttonBox.alignbuttons()


root.mainloop()
# Out:
# The "apply" button was pressed
# The "cancel" button was pressed
