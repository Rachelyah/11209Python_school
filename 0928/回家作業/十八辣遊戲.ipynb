# %% [markdown]
# ### 十八辣遊戲 用物件導向寫
# ![Alt text](image-2.png)

# %%
'''
 while (True):
        if a == b == c == d: #四個相同
            print(f"恭喜你！你骰出的是「豹子」")
            break
        elif a == b == c or a == c == d or b == c == d: #三個數字相同
            print(f"你得到零分")
            break
        elif a == b and c == d and a != c: #兩個相同&兩者相同
            if a > c:
                print(f"恭喜你！你的成績是{a + b}")
                break
            else:
                print(f"恭喜你！你的成績是{c + d}")
                break
        elif a == c and b == d and a != b:
            if a > b:
                print(f"恭喜你！你的成績是{a * 2}")
                break
            else:
                print(f"恭喜你！你的成績是{b * 2}")
                break
        elif a == d and b == c and a != b:
            if a > b:
                print(f"恭喜你！你的成績是{a * 2}")
                break
            else:
                print(f"恭喜你！你的成績是{b * 2}")
                break
        elif a == b and c != d:
            print(f"恭喜你！你的成績是{c + d}")
            break
        elif a == c and b != d:
            print(f"恭喜你！你的成績是{b + d}")
            break
        elif a == d and b != c:
            print(f"恭喜你！你的成績是{b + c}")
            break
        elif b == c and a != d:
            print(f"恭喜你！你的成績是{a + d}")
            break
        elif b == d and a != c:
            print(f"恭喜你！你的成績是{b + d}")
            break
        elif c == d and a != b:
            print(f"恭喜你！你的成績是{a + b}")
            break
        elif a != b != c != d: #四個不相同
            print("你得到零分")
            break
'''

# %%
import random
value = 0
class Player: #設定屬性，四個骰子的內容不可再寫入
    def __init__(self, name:str, dice1:int, dice2:int, dice3:int, dice4:int) :
        self.name = n
        self.__dice1 = a
        self.__dice2 = b
        self.__dice3 = c
        self.__dice4 = d

    def __play() -> int: #骰骰子＋運算結果(會不會def裡面可以多寫def？但這樣不是不太好ㄇ)
        while (True):
            a = random.randint(1, 6)
            b = random.randint(1, 6)
            c = random.randint(1, 6)
            d = random.randint(1, 6)
            if a == b == c == d: #四個數字相同
                value = a * 4
                break
            elif a == b == c or a == b == d or a == c == d or b == c == d: #三個數字相同，要重新骰
                continue
            elif a == b and c == d and a != c: #兩對
                if a > c:
                    value = a + b
                    break
                else:
                    value = c + d
                    break
            elif a == c and b == d and a != b:
                if a > b:
                    value = a * 2
                    break
                else:
                    value = b * 2 
                    break
            elif a == b and c != d:
                value = c + d
                break
            elif a == c and b != d:
                value = b + d
                break
            elif a == d and b != c:
                value = b + c
                break
            elif b == c and a != d:
                value = a + d
                break
            elif b == d and a != c:
                value = a + c
                break
            elif c == d and a != b:
                value = a + b
                break
            elif a != b != c != d: #四個不相同
                continue

    @property #onlyread結果
    def value(self) -> int:
        #呼叫self.__play()


        
        def name(self) -> str:
            return self.__name 


    def __repr__(self) -> str: #如果確定可以計分，計算&傳出結果 #這是如果只有四得一樣的寫法耶
        descript = ""
        descript += "徐國堂\n"
        descript += "骰子1=5\n"
        descript += "骰子2=3\n"
        descript += "骰子3=5\n"
        descript += "骰子4=5\n"
        dsecript += "得分=15分"
        return descript
    
    # 如果有兩個玩家可以分勝負
if __name__ == "__main__":
    p1 = Player("robert")
    print(p1.value)
    print(p1)

    p2 = Player("robert")
    print(p2.value)
    print(p2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Rachel\徐國堂\11209Python_school\0928\回家作業\十八辣遊戲.ipynb 儲存格 3 line 7
#      <a href='vscode-notebook-cell:/c%3A/Rachel/%E5%BE%90%E5%9C%8B%E5%A0%82/11209Python_school/0928/%E5%9B%9E%E5%AE%B6%E4%BD%9C%E6%A5%AD/%E5%8D%81%E5%85%AB%E8%BE%A3%E9%81%8A%E6%88%B2.ipynb#W1sZmlsZQ%3D%3D?line=76'>77</a>     # 如果有兩個玩家可以分勝負
#      <a href='vscode-notebook-cell:/c%3A/Rachel/%E5%BE%90%E5%9C%8B%E5%A0%82/11209Python_school/0928/%E5%9B%9E%E5%AE%B6%E4%BD%9C%E6%A5%AD/%E5%8D%81%E5%85%AB%E8%BE%A3%E9%81%8A%E6%88%B2.ipynb#W1sZmlsZQ%3D%3D?line=77'>78</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/c%3A/Rachel/%E5%BE%90%E5%9C%8B%E5%A0%82/11209Python_school/0928/%E5%9B%9E%E5%AE%B6%E4%BD%9C%E6%A5%AD/%E5%8D%81%E5%85%AB%E8%BE%A3%E9%81%8A%E6%88%B2.ipynb#W1sZmlsZQ%3D%3D?line=78'>79</a>     p1 = Player("robert")
# ...

# %%
import random
while (True):
            a = random.randint(1, 6)
            b = random.randint(1, 6)
            c = random.randint(1, 6)
            d = random.randint(1, 6)
            if a == b == c == d: #四個數字相同
                value = a * 4
                break
            elif a == b == c or a == b == d or a == c == d or b == c == d: #三個數字相同，要重新骰
                continue
            elif a == b and c == d and a != c: #兩對
                if a > c:
                    value = a + b
                    break
                else:
                    value = c + d
                    break
            elif a == c and b == d and a != b:
                if a > b:
                    value = a * 2
                    break
                else:
                    value = b * 2 
                    break
            elif a == b and c != d:
                value = c + d
                break
            elif a == c and b != d:
                value = b + d
                break
            elif a == d and b != c:
                value = b + c
                break
            elif b == c and a != d:
                value = a + d
                break
            elif b == d and a != c:
                value = a + c
                break
            elif c == d and a != b:
                value = a + b
                break
            elif a != b != c != d: #四個不相同
                continue

print (a, b, c, d)
print (value)
# Out:
# 1 2 4 1
# 6
