# %%
import datasource
import pandas as pd

data = datasource.lastest_datetime_data()
pd_data = pd.DataFrame(data, columns=['站點名稱', '更新時間', '行政區', '地址', '總數量', '可借', '可還'])
pd_data
# Out:
#                           站點名稱                 更新時間  行政區                   地址  \
# 0           YouBike2.0_士東路91巷口  2023-11-16 15:02:15  士林區            士東路91巷3號旁
# 1          YouBike2.0_臥龍街195巷口  2023-11-16 15:02:15  大安區      臥龍街/臥龍街195巷(南側)
# 2        YouBike2.0_辛亥路三段157巷口  2023-11-16 15:02:15  大安區  辛亥路三段與辛亥路三段157巷口西北側
# 3            YouBike2.0_臥龍基隆路口  2023-11-16 15:02:15  大安區        臥龍街與基隆路二段口東北側
# 4              YouBike2.0_敦親公園  2023-11-16 15:02:15  大安區    和平東路二段96巷8之1號(前方)
# ...                        ...                  ...  ...                  ...
# 1317  YouBike2.0_臺北科技大學(電機工程系)  2023-11-29 14:35:15  大安區         忠孝東路三段100號對側
# 1318    YouBike2.0_忠孝東路三段217巷口  2023-11-29 14:35:15  大安區        忠孝東路三段229-1號前
# 1319     YouBike2.0_新生南路三段94巷口  2023-11-29 14:35:15  大安區           新生南路三段94號前
# 1320      YouBike2.0_辛亥新生路口西北側  2023-11-29 14:35:15  大安區    辛亥路一段/新生南路三段(西北側)
# 1321    YouBike2.0_捷運大安站(6號出口)  2023-11-29 14:35:15  大安區          復興南路一段303號前
#
#       總數量  可借  可還
# 0      16  16   0
# 1      14   4  10
# 2      19   1  18
# 3      16   7   9
# 4      26   5  21
# ...   ...  ..  ..
# 1317   16   9   7
# 1318   34   0  34
# 1319   15   0  15
# 1320   12   3   9
# 1321   19   0  19
#
# [1322 rows x 7 columns]

# %%
pd_data1 = pd_data.reset_index(names='序號')
pd_data1['站點名稱'] = pd_data1['站點名稱'].map(lambda name:name[11:]) #出來的格式會是series

# %%
pd_data1
# Out:
#         序號           站點名稱                 更新時間  行政區                   地址  總數量  \
# 0        0        士東路91巷口  2023-11-16 15:02:15  士林區            士東路91巷3號旁   16
# 1        1       臥龍街195巷口  2023-11-16 15:02:15  大安區      臥龍街/臥龍街195巷(南側)   14
# 2        2     辛亥路三段157巷口  2023-11-16 15:02:15  大安區  辛亥路三段與辛亥路三段157巷口西北側   19
# 3        3         臥龍基隆路口  2023-11-16 15:02:15  大安區        臥龍街與基隆路二段口東北側   16
# 4        4           敦親公園  2023-11-16 15:02:15  大安區    和平東路二段96巷8之1號(前方)   26
# ...    ...            ...                  ...  ...                  ...  ...
# 1317  1317  臺北科技大學(電機工程系)  2023-11-29 14:35:15  大安區         忠孝東路三段100號對側   16
# 1318  1318    忠孝東路三段217巷口  2023-11-29 14:35:15  大安區        忠孝東路三段229-1號前   34
# 1319  1319     新生南路三段94巷口  2023-11-29 14:35:15  大安區           新生南路三段94號前   15
# 1320  1320      辛亥新生路口西北側  2023-11-29 14:35:15  大安區    辛亥路一段/新生南路三段(西北側)   12
# 1321  1321    捷運大安站(6號出口)  2023-11-29 14:35:15  大安區          復興南路一段303號前   19
#
#       可借  可還
# 0     16   0
# 1      4  10
# 2      1  18
# 3      7   9
# 4      5  21
# ...   ..  ..
# 1317   9   7
# 1318   0  34
# 1319   0  15
# 1320   3   9
# 1321   0  19
#
# [1322 rows x 8 columns]
